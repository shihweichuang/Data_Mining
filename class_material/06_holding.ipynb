# %%
# 讀入csv檔
import pandas as pd
file_path = './resource/holding.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %%
# 抓前5筆資料(預設即為5筆)
df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
# 前十筆資料
df.head(10)
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 6  2998623  2020/11/30              7  2021/01/08         1.63   2194727.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
# 8  2998623  2020/11/30              9  2021/01/08         1.59   1403360.0
# 9  2998623  2020/11/30             10  2021/01/08         1.54   3065766.0
#
#      market_val                     security_name     cusip
# 0  3.103426e+08                 GENERAL MOTORS CO  37045V10
# ...

# %%
# 抓倒數5筆資料(預設即為5筆)
df.tail()
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 32878713     25000.0    22294.75
# 32878714     25000.0    21480.50
# 32878715     25000.0    21484.00
# 32878716     25000.0    19187.38
# 32878717     25000.0    14971.88
#
#                                           security_name     cusip
# 32878713     Bausch Health Companies Inc 5% 30-JAN-2028  071734AH
# 32878714  Bausch Health Companies Inc 5.25% 30-JAN-2030  071734AJ
# 32878715     Bausch Health Companies Inc 5% 15-FEB-2029  071734AM
# 32878716                        Endo DAC 6% 30-JUN-2028  29273DAC
# ...

# %%
# 抓倒數n筆資料
df.tail(10)
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 32878708  3157350  2021/11/30            423  2021/12/21         0.12
# 32878709  3157350  2021/11/30            424  2021/12/21         0.12
# 32878710  3157350  2021/11/30            425  2021/12/21         0.12
# 32878711  3157350  2021/11/30            426  2021/12/21         0.11
# 32878712  3157350  2021/11/30            427  2021/12/21         0.11
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 32878708     25000.0    22810.50
# 32878709     25000.0    22726.50
# 32878710     25000.0    22700.00
# 32878711     25000.0    22685.13
# ...

# %%
# 取得特定列數資料(為連續)
df[444:449]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 444  2998809  2020/11/30             17  2021/01/08         1.96   1542737.0
# 445  2998809  2020/11/30             18  2021/01/08         1.88   1883515.0
# 446  2998809  2020/11/30             19  2021/01/08         1.80    260036.0
# 447  2998809  2020/11/30             20  2021/01/08         1.74    150444.0
# 448  2998809  2020/11/30             21  2021/01/08         1.71    725931.0
#
#       market_val                     security_name     cusip
# 444  39154665.06            EQUITABLE HOLDINGS INC  29452E10
# 445  37632629.70                     CARNIVAL CORP  14365830
# 446  35903170.52  P N C FINANCIAL SERVICES GRP INC  69347510
# 447  34778139.48                       CUMMINS INC  23102110
# 448  34278461.82             LINCOLN NATIONAL CORP  53418710

# %%
# 取得特定列數資料及欄位(可不連續)
df.loc[[444, 446], ['report_dt', 'eff_dt']]
# Out:
#       report_dt      eff_dt
# 444  2020/11/30  2021/01/08
# 446  2020/11/30  2021/01/08

# %%
# 取得特定列數資料(可不連續)及特定連續欄位
df.loc[[444, 446], 'report_dt': 'market_val']
# Out:
#       report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 444  2020/11/30             17  2021/01/08         1.96   1542737.0
# 446  2020/11/30             19  2021/01/08         1.80    260036.0
#
#       market_val
# 444  39154665.06
# 446  35903170.52

# %%
# 取得特定列數資料(可不連續)及特定連續欄位(改用索引)
df.iloc[[444, 446], 2:5]
# Out:
#      security_rank      eff_dt  percent_tna
# 444             17  2021/01/08         1.96
# 446             19  2021/01/08         1.80

# %%
df.columns  # 橫著直著看皆為series，故皆含有index
# Out:
# Index(['portno', 'report_dt', 'security_rank', 'eff_dt', 'percent_tna',
#        'nbr_shares', 'market_val', 'security_name', 'cusip'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32878718, step=1)

# %%
# 秀出所有欄位的型別：object為字串
df.dtypes
# Out:
# portno            object
# report_dt         object
# security_rank      int64
# eff_dt            object
# percent_tna      float64
# nbr_shares       float64
# market_val       float64
# security_name     object
# cusip             object
# dtype: object

# %%
# 看單一欄位型別
df['portno'].dtypes
# Out:
# dtype('O')

# %%
# 取得唯一值
df['portno'].unique()
# Out:
# array(['2998623', '2998638', '2998809', ..., '3157332', '315733e',
#        '3157350'], dtype=object)

# %%
len(df['portno'].unique())
# Out:
# 11920

# %%
# 計算平均
df['percent_tna'].mean()
# Out:
# 0.2945002086151897

# %%
# 計算加總
df['percent_tna'].sum()
# Out:
# 9682789.309999993

# %%
# 計算加總 僅能計算數值
df['cusip'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 計算加總
# ----> 2 df['cusip'].sum()
#
# File c:\users\tibame_ex14\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:11797, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11777 @doc(
#   11778     _num_doc,
#   11779     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11795     **kwargs,
#   11796 ):
# > 11797     return NDFrame.sum(
#   11798         self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11799     )
#
# File c:\users\tibame_ex14\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:11501, in NDFrame.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11492 def sum(
#   11493     self,
# ...

# %%
# 只能輸出英文，中文應該不行  建議使用df['cusip']
df.cusip
# Out:
# 0           37045V10
# 1           19244610
# 2           61744644
# 3           71817210
# 4           22052L10
#               ...
# 32878713    071734AH
# 32878714    071734AJ
# 32878715    071734AM
# 32878716    29273DAC
# 32878717    69318FAJ
# Name: cusip, Length: 32878718, dtype: object

# %%
# 同時取出多欄位
df[['nbr_shares', 'security_rank', 'percent_tna']].mean()
# Out:
# nbr_shares       4.154832e+07
# security_rank    1.077915e+03
# percent_tna      2.945002e-01
# dtype: float64

# %%
# 同時取出多欄位，若包含文字，會略過文字部分
df[['nbr_shares', 'security_rank', 'cusip']].mean()
# Out:
# C:\Users\Tibame_EX14\AppData\Local\Temp\ipykernel_24184\3002865617.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[['nbr_shares', 'security_rank', 'cusip']].mean()
# nbr_shares       4.154832e+07
# security_rank    1.077915e+03
# dtype: float64

# %%
# 計算數值出現的數量 value_counts()
df['portno'].value_counts()
# Out:
# 3066654    223027
# 3086928    185325
# 306841b    181445
# 3100110    127403
# 306920d    120721
#             ...
# 3092553         1
# 3069210         1
# 3065319         1
# 3077046         1
# 3078942         1
# Name: portno, Length: 11920, dtype: int64

# %%
# 計算每個欄位的各類數值
df.describe()
# Out:
#        security_rank   percent_tna    nbr_shares    market_val
# count   3.287872e+07  3.287872e+07  3.287872e+07  3.287872e+07
# mean    1.077915e+03  2.945002e-01  4.154832e+07  8.366760e+06
# std     1.793852e+03  1.651244e+00  8.185030e+09  1.376690e+08
# min     1.000000e+00 -2.628000e+02 -1.188360e+13 -3.157247e+10
# 25%     1.310000e+02  1.000000e-02  8.000000e+03  9.254227e+04
# 50%     4.230000e+02  4.000000e-02  1.000000e+05  5.251210e+05
# 75%     1.228000e+03  1.900000e-01  8.250000e+05  2.523780e+06
# max     1.866500e+04  3.822500e+02  9.665837e+12  7.359335e+10

# %%
# 篩選條件 該欄位是否等於指定條件
filter_portno_3086928 = (df['portno'] == '3086928')
filter_portno_3086928
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32878713    False
# 32878714    False
# 32878715    False
# 32878716    False
# 32878717    False
# Name: portno, Length: 32878718, dtype: bool

# %%
# 顯示過濾後的資料
df[filter_portno_3086928]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 896686    3086928  2020/11/30           6641  2021/01/08         0.00
# 896687    3086928  2020/11/30           8870  2021/01/08         0.00
# 896688    3086928  2020/11/30          10143  2021/01/08         0.00
# 2146348   3086928  2020/12/31              2  2021/01/22         0.59
# 2146349   3086928  2020/12/31              4  2021/01/22         0.55
# ...           ...         ...            ...         ...          ...
# 32365466  3086928  2021/11/30          15732  2021/12/21         0.00
# 32365467  3086928  2021/11/30          15732  2021/12/21         0.00
# 32365468  3086928  2021/11/30          15732  2021/12/21         0.00
# 32365469  3086928  2021/11/30          15732  2021/12/21         0.00
# 32365470  3086928  2021/11/30          15732  2021/12/21         0.00
#
#             nbr_shares    market_val  \
# 896686    5.000000e+06  5.068750e+06
# 896687    2.700000e+06  2.524500e+06
# ...

# %%
# 過濾後的資料仍為dataframe，可進行加總
df[filter_portno_3086928]['percent_tna'].sum()
# Out:
# 1062.99

# %%
# 再加上新的過濾器 (增加日期)
filter_eff_dt_20210108 = df['eff_dt'] == '2021/01/08'
filter_eff_dt_20210108
# Out:
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#             ...
# 32878713    False
# 32878714    False
# 32878715    False
# 32878716    False
# 32878717    False
# Name: eff_dt, Length: 32878718, dtype: bool

# %%
# 同時套用兩個過濾器
df[filter_portno_3086928 & filter_eff_dt_20210108]
# Out:
#          portno   report_dt  security_rank      eff_dt  percent_tna  \
# 896686  3086928  2020/11/30           6641  2021/01/08          0.0
# 896687  3086928  2020/11/30           8870  2021/01/08          0.0
# 896688  3086928  2020/11/30          10143  2021/01/08          0.0
#
#         nbr_shares  market_val  \
# 896686   5000000.0   5068750.0
# 896687   2700000.0   2524500.0
# 896688   1150000.0   1230557.5
#
#                                             security_name     cusip
# 896686                           Nov Inc 3.6% 01-DEC-2029  637071AM
# 896687                          Nov Inc 3.95% 01-DEC-2042  637071AK
# 896688  MORGAN STANLEY BK AMER MERRILL LYNCH TR 2014-C...  61690GAJ

# %%
# 再新增一過濾器檢查
filter_eff_dt_20210122 = df['eff_dt'] == '2021/01/22'

# %%
df[filter_portno_3086928 & filter_eff_dt_20210122]
# Out:
#           portno   report_dt  security_rank      eff_dt  percent_tna  \
# 2146348  3086928  2020/12/31              2  2021/01/22         0.59
# 2146349  3086928  2020/12/31              4  2021/01/22         0.55
# 2146350  3086928  2020/12/31              5  2021/01/22         0.53
# 2146351  3086928  2020/12/31              6  2021/01/22         0.53
# 2146352  3086928  2020/12/31              7  2021/01/22         0.52
# ...          ...         ...            ...         ...          ...
# 2156215  3086928  2020/12/31          12469  2021/01/22         0.00
# 2156216  3086928  2020/12/31          12469  2021/01/22         0.00
# 2156217  3086928  2020/12/31          12469  2021/01/22         0.00
# 2156218  3086928  2020/12/31          12469  2021/01/22         0.00
# 2156219  3086928  2020/12/31          12469  2021/01/22         0.00
#
#            nbr_shares    market_val  \
# 2146348  1.308350e+09  1.304466e+09
# 2146349  1.216645e+09  1.216265e+09
# ...

# %%
df[filter_portno_3086928 & filter_eff_dt_20210122]['percent_tna'].sum()
# Out:
# 75.17

# %% [markdown]
# # groupby

# %%
df.groupby('portno')

# %%
df.groupby('portno').size()
# Out:
# portno
# 2998623    4155
# 2998638     929
# 2998809     862
# 2998821     629
# 2998923     420
#            ...
# 315733b      16
# 315733e     363
# 3157347       5
# 315734a       3
# 3157350     428
# Length: 11920, dtype: int64

# %%
df[filter_portno_3086928].groupby('eff_dt').sum()
# Out:
# C:\Users\Tibame_EX14\AppData\Local\Temp\ipykernel_24184\243356993.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[filter_portno_3086928].groupby('eff_dt').sum()
#             security_rank  percent_tna    nbr_shares    market_val
# eff_dt
# 2021/01/08          25654         0.00  8.850000e+06  8.823808e+06
# 2021/01/22       60374576        75.17  1.669894e+11  1.839840e+11
# 2021/02/05       47855464        14.13  3.444157e+10  3.660731e+10
# 2021/02/19      109317650        88.98  2.073548e+11  2.246429e+11
# 2021/03/08         147381         0.23  4.657860e+08  5.086744e+08
# 2021/03/23      111176945        87.88  2.138652e+11  2.275794e+11
# 2021/04/09         380627         0.95  2.292230e+09  2.243601e+09
# 2021/04/23      119570706        88.54  2.230770e+11  2.332506e+11
# ...

# %%
# 換另一portno並換groupby選項
df[df['portno'] == '2998623'].groupby('report_dt').sum()
# Out:
# C:\Users\Tibame_EX14\AppData\Local\Temp\ipykernel_24184\4211509919.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['portno'] == '2998623'].groupby('report_dt').sum()
#             security_rank  percent_tna    nbr_shares    market_val
# report_dt
# 2020/11/30          61888        99.79  3.817768e+09  1.213476e+10
# 2020/12/31          61544        99.76  3.894819e+09  1.232999e+10
# 2021/01/31          60135        99.77  3.936475e+09  1.203395e+10
# 2021/02/28          57735        99.80  3.980795e+09  1.257758e+10
# 2021/03/31          61166       100.01  4.637393e+09  1.290277e+10
# 2021/04/30          60465        99.96  4.606629e+09  1.325873e+10
# 2021/05/31          61501        99.97  4.503789e+09  1.339596e+10
# ...

# %%
# 直接groupby兩欄位，如果資料量太多，可以優先抓取指定數量，避免點點點發生(不易識別)
df.groupby(['portno', 'report_dt']).sum().head(30)
# Out:
# C:\Users\Tibame_EX14\AppData\Local\Temp\ipykernel_24184\4061202001.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['portno', 'report_dt']).sum().head(30)
#                     security_rank  percent_tna    nbr_shares    market_val
# portno  report_dt
# 2998623 2020/11/30          61888        99.79  3.817768e+09  1.213476e+10
#         2020/12/31          61544        99.76  3.894819e+09  1.232999e+10
#         2021/01/31          60135        99.77  3.936475e+09  1.203395e+10
#         2021/02/28          57735        99.80  3.980795e+09  1.257758e+10
#         2021/03/31          61166       100.01  4.637393e+09  1.290277e+10
#         2021/04/30          60465        99.96  4.606629e+09  1.325873e+10
# ...

# %%
# 列出所有欄位
df.columns
# Out:
# Index(['portno', 'report_dt', 'security_rank', 'eff_dt', 'percent_tna',
#        'nbr_shares', 'market_val', 'security_name', 'cusip'],
#       dtype='object')

# %%
# 確認不同欄位 資料量是否一致
print(len(df['security_name'].unique()))
print(len(df['cusip'].unique()))
# Out:
# 707303
# 430883

# %%
# 判斷是否有空值
df[df['security_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [portno, report_dt, security_rank, eff_dt, percent_tna, nbr_shares, market_val, security_name, cusip]
# Index: []

# %%
# 判斷是否有空值
df[df['cusip'].isna()]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 66        2998623  2020/11/30             67  2021/01/08         0.60
# 69        2998623  2020/11/30             70  2021/01/08         0.53
# 74        2998623  2020/11/30             75  2021/01/08         0.51
# 77        2998623  2020/11/30             78  2021/01/08         0.50
# 85        2998623  2020/11/30             86  2021/01/08         0.41
# ...           ...         ...            ...         ...          ...
# 32877366  315724b  2021/11/30             48  2021/12/21         1.02
# 32877420  315724e  2021/11/30             52  2021/12/21         0.00
# 32877926  3157332  2021/11/30            506  2021/12/21        -0.05
# 32878078  315733e  2021/11/30            152  2021/12/21         0.60
# 32878291  3157350  2021/11/30              2  2021/12/21         1.76
#
#           nbr_shares   market_val  \
# 66        60368000.0  72622704.00
# 69        56758000.0  64023024.00
# ...

# %%
# 判斷是否有空字串
df[df['security_name'] == '']
# Out:
# Empty DataFrame
# Columns: [portno, report_dt, security_rank, eff_dt, percent_tna, nbr_shares, market_val, security_name, cusip]
# Index: []

# %%
# 判斷是否有空字串
df[df['cusip'] == '']
# Out:
# Empty DataFrame
# Columns: [portno, report_dt, security_rank, eff_dt, percent_tna, nbr_shares, market_val, security_name, cusip]
# Index: []

# %%
# 取出空值的security_name，有沒有存在cusip不是空值 ----> 聽不懂
df[df['security_name'].notna()]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %%
# 老師忘記怎麼處理~~~~~~~~~~~~~~~~~~~~~~

print(
    len(df[df['security_name'].notna()]['security_name'].unique())
)
print(
    len(df[df['security_name'].notna()]['cusip'].unique())
)
# Out:
# 707303
# 430883
